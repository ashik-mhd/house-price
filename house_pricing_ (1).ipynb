# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler,LabelEncoder

# %%
data_hs=pd.read_csv('/content/House_Pricing.csv')
data_hs.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
data_hs.shape
# Out:
# (21613, 21)

# %%
data_hs.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
data_hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data_hs.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
data_hs.drop(columns=['No of Times Visited'],inplace=True)
data_hs.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
data_hs['ID'].value_counts()
# Out:
# ID
# 795000620     3
# 8651510380    2
# 2568300045    2
# 9353300600    2
# 4139480200    2
#              ..
# 2767603649    1
# 1446403617    1
# 5602000275    1
# 1786200010    1
# 1523300157    1
# Name: count, Length: 21436, dtype: int64

# %%
data_hs.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
sns.histplot(data_hs['Sale Price'],kde=True)
# Out:
# <Axes: xlabel='Sale Price', ylabel='Count'>

# %%
sns.histplot(data_hs['No of Bathrooms'],kde=True)
# Out:
# <Axes: xlabel='No of Bathrooms', ylabel='Count'>

# %%
sns.histplot(data_hs['Flat Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Flat Area (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data_hs['Lot Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Lot Area (in Sqft)', ylabel='Count'>

# %%
sns.histplot(data_hs['Area of the House from Basement (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Area of the House from Basement (in Sqft)', ylabel='Count'>

# %%
data_hs['Sale Price'].fillna(data_hs['Sale Price'].mode()[0],inplace=True)
data_hs['No of Bathrooms'].fillna(data_hs['No of Bathrooms'].mode()[0],inplace=True)
data_hs.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
data_hs['Flat Area (in Sqft)'].fillna(data_hs['Flat Area (in Sqft)'].mode()[0],inplace=True)
data_hs['Lot Area (in Sqft)'].fillna(data_hs['Lot Area (in Sqft)'].mode()[0],inplace=True)
data_hs.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
data_hs['Area of the House from Basement (in Sqft)'].fillna(data_hs['Area of the House from Basement (in Sqft)'].mode()[0],inplace=True)
data_hs['Living Area after Renovation (in Sqft)'].fillna(data_hs['Living Area after Renovation (in Sqft)'].mode()[0],inplace=True)
data_hs.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
data_hs['Zipcode'].fillna(data_hs['Zipcode'].mode()[0],inplace=True)
data_hs['Latitude'].fillna(data_hs['Latitude'].mode()[0],inplace=True)
data_hs['Longitude'].fillna(data_hs['Longitude'].mode()[0],inplace=True)
data_hs.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# ...

# %%
data_hs.nunique()
# Out:
# ID                                           21436
# Date House was Sold                             13
# Sale Price                                    3625
# No of Bedrooms                                  13
# No of Bathrooms                                 30
# Flat Area (in Sqft)                           1036
# Lot Area (in Sqft)                            9778
# No of Floors                                     6
# Waterfront View                                  2
# Condition of the House                           5
# Overall Grade                                   10
# Area of the House from Basement (in Sqft)      946
# Basement Area (in Sqft)                        306
# Age of House (in Years)                        116
# Renovated Year                                  70
# Zipcode                                         70
# Latitude                                      5034
# Longitude                                      752
# ...

# %%
data_hs.shape
# Out:
# (21613, 21)

# %%
data_hs.ID.unique()
# Out:
# array([7129300520, 6414100192, 5631500400, ..., 1523300141,  291310100,
#        1523300157])

# %%
data_hs.ID.value_counts()
# Out:
# ID
# 795000620     3
# 8651510380    2
# 2568300045    2
# 9353300600    2
# 4139480200    2
#              ..
# 2767603649    1
# 1446403617    1
# 5602000275    1
# 1786200010    1
# 1523300157    1
# Name: count, Length: 21436, dtype: int64

# %%
data_hs.ID.nunique()
# Out:
# 21436

# %%
fig,ax=plt.subplots(1,9,figsize=(15,2),constrained_layout=True)

ax[0].hist(data_hs['No of Bedrooms'])
ax[0].set_title('No of Bedrooms')

ax[1].hist(data_hs['Flat Area (in Sqft)'])
ax[1].set_title('Flat Area (in Sqft)')

ax[2].hist(data_hs['Lot Area (in Sqft)'])
ax[2].set_title('Lot Area (in Sqft)')

ax[3].hist(data_hs['Area of the House from Basement (in Sqft)'])
ax[3].set_title('Area of the House from Basement (in Sqft)')

ax[4].hist(data_hs['Basement Area (in Sqft)'])
ax[4].set_title('Basement Area (in Sqft)')

ax[5].hist(data_hs['Latitude'])
ax[5].set_title('Latitude')

ax[6].hist(data_hs['Longitude'])
ax[6].set_title('Longitude')

ax[7].hist(data_hs['Living Area after Renovation (in Sqft)'])
ax[7].set_title('Living Area after Renovation (in Sqft)')

ax[8].hist(data_hs['Lot Area after Renovation (in Sqft)'])
ax[8].set_title('Lot Area after Renovation (in Sqft)')

plt.show()

# %%
fig,ax=plt.subplots(1,9,figsize=(15,2),constrained_layout=True)

ax[0].boxplot(data_hs['No of Bedrooms'])
ax[0].set_title('No of Bedrooms')

ax[1].boxplot(data_hs['Flat Area (in Sqft)'])
ax[1].set_title('Flat Area (in Sqft)')

ax[2].boxplot(data_hs['Lot Area (in Sqft)'])
ax[2].set_title('Lot Area (in Sqft)')

ax[3].boxplot(data_hs['Area of the House from Basement (in Sqft)'])
ax[3].set_title('Area of the House from Basement (in Sqft)')

ax[4].boxplot(data_hs['Basement Area (in Sqft)'])
ax[4].set_title('Basement Area (in Sqft)')

ax[5].boxplot(data_hs['Latitude'])
ax[5].set_title('Latitude')

ax[6].boxplot(data_hs['Longitude'])
ax[6].set_title('Longitude')

ax[7].boxplot(data_hs['Living Area after Renovation (in Sqft)'])
ax[7].set_title('Living Area after Renovation (in Sqft)')

ax[8].boxplot(data_hs['Lot Area after Renovation (in Sqft)'])
ax[8].set_title('Lot Area after Renovation (in Sqft)')

plt.show()

# %%
label_encoder = LabelEncoder()
data_hs['ID_encoded'] = label_encoder.fit_transform(data_hs['ID'])
data_hs
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
categorical_cols = ['Waterfront View','Condition of the House']

# %%
numerical_cols = ['Sale Price','No of Bedrooms','Flat Area (in Sqft)','Age of House (in Years)']

# %%
data_hs.ID_encoded.nunique()
# Out:
# 21436

# %%
data_hs_encoded = pd.get_dummies(data_hs, columns=categorical_cols,dtype=int,drop_first=True)
data_hs_encoded.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                 NaN              7  ...   47.5112   -122.257
# ...

# %%
data_hs_std_scaled = data_hs_encoded.copy()

std_scaler = StandardScaler()
data_hs_std_scaled[numerical_cols] = std_scaler.fit_transform(data_hs_std_scaled[numerical_cols])
data_hs_std_scaled.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017   -0.866400       -0.398737
# 1  6414100192    14 December 2017   -0.005984       -0.398737
# 2  5631500400    15 February 2016   -0.980451       -1.473959
# 3  2487200875    14 December 2017    0.173666        0.676485
# 4  1954400510    15 February 2016   -0.082199       -0.398737
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00            -0.979820              5650.0           1.0
# 1             2.25             0.533572              7242.0           2.0
# 2             1.00            -1.426216             10000.0           1.0
# 3             3.00            -0.130578              5000.0           1.0
# 4             2.00            -0.435434              8080.0           1.0
#
#   No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                 NaN              7  ...   47.5112   -122.257
# ...

# %%
data_hs_encoded.shape
# Out:
# (21613, 25)

# %%
data_hs_std_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    2.161300e+04     21609.000000
# mean   4.580302e+09 -4.471924e-17    2.367051e-16         2.114732
# std    2.876566e+09  1.000023e+00    1.000023e+00         0.770138
# min    1.000102e+06 -1.266258e+00   -3.624404e+00         0.000000
# 25%    2.123049e+09 -5.940665e-01   -3.987371e-01         1.750000
# 50%    3.904930e+09 -2.455178e-01   -3.987371e-01         2.250000
# 75%    7.308900e+09  2.852671e-01    6.764851e-01         2.500000
# max    9.900000e+09  1.948879e+01    3.185793e+01         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         2.160400e+04        2.160400e+04  21613.000000   21613.000000
# mean         -1.184019e-16        1.510776e+04      1.494309       7.623467
# std           1.000023e+00        4.142827e+04      0.539989       1.105439
# ...

# %%
data_hs_minmax_scaled =data_hs_encoded.copy()

minmax_scaler = MinMaxScaler()
data_hs_minmax_scaled[numerical_cols] = minmax_scaler.fit_transform(data_hs_minmax_scaled[numerical_cols])
data_hs_minmax_scaled.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    0.019266        0.090909
# 1  6414100192    14 December 2017    0.060721        0.090909
# 2  5631500400    15 February 2016    0.013770        0.060606
# 3  2487200875    14 December 2017    0.069377        0.121212
# 4  1954400510    15 February 2016    0.057049        0.090909
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00             0.067170              5650.0           1.0
# 1             2.25             0.172075              7242.0           2.0
# 2             1.00             0.036226             10000.0           1.0
# 3             3.00             0.126038              5000.0           1.0
# 4             2.00             0.104906              8080.0           1.0
#
#   No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                 NaN              7  ...   47.5112   -122.257
# ...

# %%
corr_cols = ['Sale Price','No of Bedrooms','Flat Area (in Sqft)','Age of House (in Years)']
ori_data_corr =data_hs_encoded[corr_cols].corr()
ori_data_corr.head()
# Out:
#                          Sale Price  No of Bedrooms  Flat Area (in Sqft)  \
# Sale Price                 1.000000        0.308463             0.702081
# No of Bedrooms             0.308463        1.000000             0.576616
# Flat Area (in Sqft)        0.702081        0.576616             1.000000
# Age of House (in Years)   -0.054034       -0.154178            -0.318207
#
#                          Age of House (in Years)
# Sale Price                             -0.054034
# No of Bedrooms                         -0.154178
# Flat Area (in Sqft)                    -0.318207
# Age of House (in Years)                 1.000000

# %%
stdscaled_data_hs_corr =data_hs_std_scaled[corr_cols].corr()
stdscaled_data_hs_corr.head()
# Out:
#                          Sale Price  No of Bedrooms  Flat Area (in Sqft)  \
# Sale Price                 1.000000        0.308463             0.702081
# No of Bedrooms             0.308463        1.000000             0.576616
# Flat Area (in Sqft)        0.702081        0.576616             1.000000
# Age of House (in Years)   -0.054034       -0.154178            -0.318207
#
#                          Age of House (in Years)
# Sale Price                             -0.054034
# No of Bedrooms                         -0.154178
# Flat Area (in Sqft)                    -0.318207
# Age of House (in Years)                 1.000000

# %%
minmaxscaled_data_corr = data_hs_minmax_scaled[corr_cols].corr()
minmaxscaled_data_corr.head()
# Out:
#                          Sale Price  No of Bedrooms  Flat Area (in Sqft)  \
# Sale Price                 1.000000        0.308463             0.702081
# No of Bedrooms             0.308463        1.000000             0.576616
# Flat Area (in Sqft)        0.702081        0.576616             1.000000
# Age of House (in Years)   -0.054034       -0.154178            -0.318207
#
#                          Age of House (in Years)
# Sale Price                             -0.054034
# No of Bedrooms                         -0.154178
# Flat Area (in Sqft)                    -0.318207
# Age of House (in Years)                 1.000000

# %%
sns.heatmap(ori_data_corr,annot=True,cmap='viridis')
plt.show()
